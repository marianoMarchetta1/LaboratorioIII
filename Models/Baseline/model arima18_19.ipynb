# %% [markdown]
# #### Este baseline se basara en armar un modelo LSTM por cada producto, con una optimizacion de hiper parametros escueta, para poder comparar con futuros experimientos. En caso de que esta alternativa funcione bien, seria recomendable incorporar parametros de optimizacion extra.

# %% [markdown]
# #### Imports

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

# %%
final_dataset = pd.read_csv('../../Datasets/final_dataset.csv', sep='\t')

# %%
final_dataset.head()
# Out:
#    periodo  product_id  plan_precios_cuidados  cust_request_qty
# 0   201701       20001                      0               479  \
# 1   201702       20001                      0               432
# 2   201703       20001                      0               509
# 3   201704       20001                      0               279
# 4   201705       20001                      0               701
#
#    cust_request_tn           y cat1         cat2     cat3  brand  sku_size
# 0        937.72717   934.77222   HC  ROPA LAVADO  Liquido  ARIEL      3000  \
# 1        833.72187   798.01620   HC  ROPA LAVADO  Liquido  ARIEL      3000
# 2       1330.74697  1303.35771   HC  ROPA LAVADO  Liquido  ARIEL      3000
# 3       1132.94430  1069.96130   HC  ROPA LAVADO  Liquido  ARIEL      3000
# 4       1550.68936  1502.20132   HC  ROPA LAVADO  Liquido  ARIEL      3000
#
#    stock_final  close_quarter  age
# 0          NaN              0    0
# 1          NaN              0    1
# 2          NaN              1    2
# 3          NaN              0    3
# 4          NaN              0    4

# %%
# Asegurarse de que la columna 'periodo' sea de tipo string
final_dataset['periodo'] = final_dataset['periodo'].astype(str)
final_dataset = final_dataset[final_dataset['periodo'].str.startswith(('2019', '2018'))]
final_dataset.head()
# Out:
#    periodo  product_id  plan_precios_cuidados  cust_request_qty
# 12  201801       20001                      0               437  \
# 13  201802       20001                      0               302
# 14  201803       20001                      0               591
# 15  201804       20001                      0               384
# 16  201805       20001                      0               456
#
#     cust_request_tn           y cat1         cat2     cat3  brand  sku_size
# 12       1256.01136  1169.07532   HC  ROPA LAVADO  Liquido  ARIEL      3000  \
# 13       1150.37849  1043.76470   HC  ROPA LAVADO  Liquido  ARIEL      3000
# 14       1902.79056  1856.83534   HC  ROPA LAVADO  Liquido  ARIEL      3000
# 15       1286.12277  1251.28462   HC  ROPA LAVADO  Liquido  ARIEL      3000
# 16       1303.62129  1293.89788   HC  ROPA LAVADO  Liquido  ARIEL      3000
#
#     stock_final  close_quarter  age
# 12          NaN              0   12
# 13          NaN              0   13
# 14          NaN              1   14
# 15          NaN              0   15
# 16          NaN              0   16

# %%
columns = ['plan_precios_cuidados', 'cust_request_qty', 'cust_request_tn', 'close_quarter','y']

# %% [markdown]
# #### Funcion para crear los modelos

# %% [markdown]
# #### Armado de los modelos

# %%
import os
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import joblib

product_ids = final_dataset['product_id'].unique()
predictions = []
    
for product_id in product_ids:
    product_data = final_dataset[final_dataset['product_id'] == product_id].sort_values(by='periodo')[columns]
    
    product_data_array = product_data['y'].values
    
       
    model = auto_arima(product_data_array, seasonal=True, trace=True, error_action='ignore', suppress_warnings=True)

    os.makedirs('Arima_results', exist_ok=True)
    joblib.dump(model, f'Models_params/model_product_{product_id}.pkl')
    
    forecast_steps = 2
    forecast = model.predict(n_periods=forecast_steps)
    
    # Agregar predicción al resultado
    predicted_y = forecast[-1]
    predictions.append({'product_id': product_id, 'predicted_y': predicted_y})

    print(f'Modelo para el producto {product_id} entrenado y guardado. Predicción a 2 meses: {predicted_y}')
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=350.325, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=343.021, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=344.984, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=344.984, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=421.368, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=347.209, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.610 seconds
# Modelo para el producto 20001 entrenado y guardado. Predicción a 2 meses: 1480.3078595833342
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=345.793, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=341.578, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=342.294, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=341.607, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=408.977, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=343.541, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.350 seconds
# Modelo para el producto 20002 entrenado y guardado. Predicción a 2 meses: 1131.4006833333335
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=321.776, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=323.347, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=316.818, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=317.264, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=393.931, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=318.674, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=318.681, Time=0.18 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=320.169, Time=0.26 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=324.310, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.932 seconds
# Modelo para el producto 20003 entrenado y guardado. Predicción a 2 meses: 852.802840952994
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=317.071, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=319.093, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=313.886, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=312.294, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=381.961, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=313.761, Time=0.15 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=313.541, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=314.491, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.829 seconds
# Modelo para el producto 20004 entrenado y guardado. Predicción a 2 meses: 637.4579177716992
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=324.496, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=324.191, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=319.778, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=319.889, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=381.120, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=321.165, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=321.295, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=323.259, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=326.439, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.488 seconds
# Modelo para el producto 20005 entrenado y guardado. Predicción a 2 meses: 612.2584210606713
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=313.584, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=311.421, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=312.010, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=373.556, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=313.382, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=313.385, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=315.378, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=319.777, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.574 seconds
# Modelo para el producto 20006 entrenado y guardado. Predicción a 2 meses: 511.53121968381515
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=321.029, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=313.226, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=319.075, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=310.033, Time=0.20 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=311.911, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=312.160, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=312.663, Time=0.34 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=308.888, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=311.307, Time=0.01 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=310.886, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=310.559, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=310.548, Time=0.11 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=311.509, Time=0.23 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0]
# Total fit time: 2.701 seconds
# Modelo para el producto 20007 entrenado y guardado. Predicción a 2 meses: 374.60790109910505
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=288.594, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=290.181, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=286.828, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.697 seconds
# Modelo para el producto 20008 entrenado y guardado. Predicción a 2 meses: 195.3685399999999
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=287.616, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=284.920, Time=0.36 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=285.790, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=286.722, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=283.466, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=285.342, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=284.669, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=282.784, Time=0.04 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=284.726, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=285.931, Time=0.15 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.163 seconds
# Modelo para el producto 20009 entrenado y guardado. Predicción a 2 meses: 570.3656738743032
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=609.600, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=594.699, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=721.225, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=592.555, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=594.432, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=608.144, Time=0.05 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 1.148 seconds
# Modelo para el producto 20010 entrenado y guardado. Predicción a 2 meses: 414.1118483701366
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=296.274, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=298.343, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=290.633, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=291.264, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=356.406, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=292.704, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=292.542, Time=0.19 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=294.469, Time=0.35 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=296.888, Time=0.03 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 1.108 seconds
# Modelo para el producto 20011 entrenado y guardado. Predicción a 2 meses: 378.8131296697535
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=297.456, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=296.422, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=295.508, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.785 seconds
# Modelo para el producto 20012 entrenado y guardado. Predicción a 2 meses: 173.13004000000006
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=290.711, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=289.954, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=289.237, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=360.461, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=291.348, Time=0.08 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=293.192, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=344.456, Time=0.04 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.850 seconds
# Modelo para el producto 20013 entrenado y guardado. Predicción a 2 meses: 415.9483896087003
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=296.912, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=290.346, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=292.332, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=292.312, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=363.015, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=293.609, Time=0.17 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.492 seconds
# Modelo para el producto 20014 entrenado y guardado. Predicción a 2 meses: 436.78062541666645
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=289.154, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=282.467, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=283.676, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=283.484, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=357.798, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=285.464, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.411 seconds
# Modelo para el producto 20015 entrenado y guardado. Predicción a 2 meses: 392.74896583333333
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=268.526, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=268.072, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=267.369, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=266.628, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.623 seconds
# Modelo para el producto 20016 entrenado y guardado. Predicción a 2 meses: 273.20202
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=271.319, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=273.312, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=273.308, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=269.356, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=274.926, Time=0.18 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.625 seconds
# Modelo para el producto 20017 entrenado y guardado. Predicción a 2 meses: 216.90772999999987
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=282.691, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=283.757, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=280.854, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.418 seconds
# Modelo para el producto 20018 entrenado y guardado. Predicción a 2 meses: 141.6357
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=296.366, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=295.374, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=295.784, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=353.803, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=297.115, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=297.229, Time=0.19 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=299.363, Time=0.23 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=304.382, Time=0.03 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 1.090 seconds
# Modelo para el producto 20019 entrenado y guardado. Predicción a 2 meses: 351.62207520086207
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=515.023, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=553.341, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=513.404, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=521.584, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=684.166, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=514.626, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=513.016, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=513.071, Time=0.31 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=513.022, Time=0.45 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=515.894, Time=0.26 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=522.472, Time=0.06 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 1.674 seconds
# Modelo para el producto 20020 entrenado y guardado. Predicción a 2 meses: 280.3235897080598
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=567.849, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=556.647, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=682.337, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=552.928, Time=0.09 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=554.924, Time=0.11 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=571.880, Time=0.05 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 1.321 seconds
# Modelo para el producto 20021 entrenado y guardado. Predicción a 2 meses: 285.7311932501829
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=552.546, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=588.736, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=554.183, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=556.809, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=668.749, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=550.550, Time=0.16 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=553.009, Time=0.13 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=551.399, Time=0.11 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=552.536, Time=0.17 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=554.772, Time=0.20 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=550.257, Time=0.37 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=553.354, Time=0.40 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=552.598, Time=0.40 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=550.978, Time=0.25 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=551.322, Time=0.33 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=554.630, Time=0.41 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=557.399, Time=0.20 sec
#
# Best model:  ARIMA(2,0,3)(0,0,0)[0] intercept
# Total fit time: 3.820 seconds
# Modelo para el producto 20022 entrenado y guardado. Predicción a 2 meses: 197.94155853909012
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=281.123, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=273.161, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=275.125, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=275.125, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=340.945, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=277.125, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.332 seconds
# Modelo para el producto 20023 entrenado y guardado. Predicción a 2 meses: 274.3351975
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=274.815, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=275.105, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=275.666, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=337.337, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=275.755, Time=0.14 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.546 seconds
# Modelo para el producto 20024 entrenado y guardado. Predicción a 2 meses: 252.6601350000001
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=274.652, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=267.907, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=269.334, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=269.438, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=335.247, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=271.279, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.452 seconds
# Modelo para el producto 20025 entrenado y guardado. Predicción a 2 meses: 243.49620750000008
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=269.975, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=275.949, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=269.876, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=264.406, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=340.189, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=265.983, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=265.826, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=268.116, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.647 seconds
# Modelo para el producto 20026 entrenado y guardado. Predicción a 2 meses: 268.7264159141268
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=244.490, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=241.352, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=331.590, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=243.497, Time=0.20 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=240.374, Time=0.19 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=245.998, Time=0.23 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 1.374 seconds
# Modelo para el producto 20027 entrenado y guardado. Predicción a 2 meses: 242.7101512413638
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=275.776, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=272.575, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=271.149, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=272.394, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=330.953, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=271.907, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=271.921, Time=0.16 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=273.909, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=295.426, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.689 seconds
# Modelo para el producto 20028 entrenado y guardado. Predicción a 2 meses: 204.11695087274146
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=261.348, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=260.571, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=259.377, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.468 seconds
# Modelo para el producto 20029 entrenado y guardado. Predicción a 2 meses: 150.64868999999993
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=262.174, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=259.240, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=260.620, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=260.209, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=260.483, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=260.486, Time=0.10 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=257.722, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=258.625, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=258.771, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=259.378, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=260.572, Time=0.08 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 1.020 seconds
# Modelo para el producto 20030 entrenado y guardado. Predicción a 2 meses: 101.20147033595472
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=272.878, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=274.755, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=274.795, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=329.511, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=276.060, Time=0.18 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.544 seconds
# Modelo para el producto 20031 entrenado y guardado. Predicción a 2 meses: 212.45805208333343
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=262.827, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=257.249, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=259.383, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=325.543, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=258.785, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=259.074, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=262.345, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.743 seconds
# Modelo para el producto 20033 entrenado y guardado. Predicción a 2 meses: 161.04954939008226
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=249.645, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=243.280, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=244.295, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=244.541, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=321.257, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=245.786, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.520 seconds
# Modelo para el producto 20035 entrenado y guardado. Predicción a 2 meses: 183.8408212500001
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=541.446, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=575.916, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=540.372, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=547.100, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=650.097, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=541.324, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=540.782, Time=0.11 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=544.039, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.940 seconds
# Modelo para el producto 20037 entrenado y guardado. Predicción a 2 meses: 111.4509449368436
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=254.653, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=249.084, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=251.059, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=251.055, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=319.259, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=253.073, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.466 seconds
# Modelo para el producto 20038 entrenado y guardado. Predicción a 2 meses: 175.0861691666667
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=252.474, Time=0.43 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=250.696, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=248.864, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=249.577, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=315.109, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=250.814, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=250.785, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=252.784, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=257.417, Time=0.01 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.905 seconds
# Modelo para el producto 20039 entrenado y guardado. Predicción a 2 meses: 154.92422206562551
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=256.524, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=249.981, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=251.455, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=251.031, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=315.328, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=252.599, Time=0.18 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.513 seconds
# Modelo para el producto 20041 entrenado y guardado. Predicción a 2 meses: 160.3817545833334
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=248.234, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=244.816, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=246.737, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=246.692, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=316.237, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=248.802, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.464 seconds
# Modelo para el producto 20042 entrenado y guardado. Predicción a 2 meses: 164.62073875000007
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=262.402, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=254.847, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=260.425, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=254.021, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=251.923, Time=0.13 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=253.893, Time=0.16 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=251.832, Time=0.32 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=253.388, Time=0.36 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=252.843, Time=0.35 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0] intercept
# Total fit time: 2.762 seconds
# Modelo para el producto 20043 entrenado y guardado. Predicción a 2 meses: 117.73133033432929
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=266.184, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=263.827, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=265.793, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=265.557, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=317.145, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=267.378, Time=0.17 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.564 seconds
# Modelo para el producto 20044 entrenado y guardado. Predicción a 2 meses: 163.04669624999997
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=260.349, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=255.788, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=255.458, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=256.248, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=319.944, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=256.302, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=256.580, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=258.290, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=264.807, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.676 seconds
# Modelo para el producto 20045 entrenado y guardado. Predicción a 2 meses: 172.19098087243015
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=251.915, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=247.513, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=246.562, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=246.014, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=313.129, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=247.998, Time=0.09 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=247.982, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=249.940, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=292.416, Time=0.04 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.590 seconds
# Modelo para el producto 20046 entrenado y guardado. Predicción a 2 meses: 153.01241313199856
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=262.008, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=257.155, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=258.436, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=258.605, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=316.681, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=258.016, Time=0.24 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.616 seconds
# Modelo para el producto 20047 entrenado y guardado. Predicción a 2 meses: 163.50465458333332
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=258.411, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=252.367, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=254.368, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=254.367, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=312.151, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=255.643, Time=0.21 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.472 seconds
# Modelo para el producto 20050 entrenado y guardado. Predicción a 2 meses: 148.84395291666675
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=271.783, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=272.237, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=272.403, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=319.697, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=274.114, Time=0.19 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.592 seconds
# Modelo para el producto 20051 entrenado y guardado. Predicción a 2 meses: 169.52384083333337
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=248.355, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=253.355, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=245.736, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=251.491, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=246.362, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=244.804, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=244.865, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=245.198, Time=0.05 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 1.273 seconds
# Modelo para el producto 20052 entrenado y guardado. Predicción a 2 meses: 93.26874747218545
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=236.916, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=229.577, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=231.574, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=231.572, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=310.362, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=233.543, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.414 seconds
# Modelo para el producto 20053 entrenado y guardado. Predicción a 2 meses: 146.80841999999987
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=253.490, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=253.041, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=252.751, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=308.193, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=254.688, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=254.554, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=254.266, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=291.023, Time=0.04 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.885 seconds
# Modelo para el producto 20054 entrenado y guardado. Predicción a 2 meses: 135.28698852208495
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=254.932, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=244.753, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=253.058, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=246.132, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=243.114, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=244.629, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=244.271, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=243.460, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=246.165, Time=0.08 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 1.106 seconds
# Modelo para el producto 20055 entrenado y guardado. Predicción a 2 meses: 64.31469588522347
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=273.204, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=271.465, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=271.216, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.450 seconds
# Modelo para el producto 20056 entrenado y guardado. Predicción a 2 meses: 63.7182
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=240.816, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=239.301, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=241.245, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=241.161, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=308.668, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=242.745, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.474 seconds
# Modelo para el producto 20057 entrenado y guardado. Predicción a 2 meses: 140.2956491666667
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=235.579, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=228.819, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=230.224, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=230.363, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=304.637, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=232.319, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.352 seconds
# Modelo para el producto 20058 entrenado y guardado. Predicción a 2 meses: 129.8104820833334
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=244.314, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=240.415, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=239.761, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=238.588, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=305.611, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=240.318, Time=0.22 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=240.327, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=242.334, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=284.146, Time=0.04 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.735 seconds
# Modelo para el producto 20059 entrenado y guardado. Predicción a 2 meses: 130.4214599586173
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=246.408, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=240.471, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=241.044, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=240.576, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=305.143, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=242.496, Time=0.13 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.399 seconds
# Modelo para el producto 20061 entrenado y guardado. Predicción a 2 meses: 129.59922916666676
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=240.379, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=238.164, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=233.631, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=297.421, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=235.621, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=235.613, Time=0.11 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=237.391, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=275.107, Time=0.03 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.872 seconds
# Modelo para el producto 20062 entrenado y guardado. Predicción a 2 meses: 109.02023397665623
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=232.064, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=232.179, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=231.244, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=303.374, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=230.086, Time=0.20 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=235.828, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=233.729, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 1.275 seconds
# Modelo para el producto 20063 entrenado y guardado. Predicción a 2 meses: 119.86953105601307
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=250.013, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=252.009, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=252.008, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=304.698, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=253.999, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.482 seconds
# Modelo para el producto 20065 entrenado y guardado. Predicción a 2 meses: 126.18913124999999
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=238.095, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=239.444, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=239.574, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=300.637, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=241.639, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.426 seconds
# Modelo para el producto 20066 entrenado y guardado. Predicción a 2 meses: 117.62440666666669
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=251.716, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=253.357, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=253.158, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=302.004, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=252.670, Time=0.22 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.524 seconds
# Modelo para el producto 20067 entrenado y guardado. Predicción a 2 meses: 118.04737875000004
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=218.642, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=212.520, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=213.231, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=213.144, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=299.158, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=215.137, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.411 seconds
# Modelo para el producto 20068 entrenado y guardado. Predicción a 2 meses: 116.65949791666671
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=238.400, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=234.463, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=236.463, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=236.462, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=303.168, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.563 seconds
# Modelo para el producto 20069 entrenado y guardado. Predicción a 2 meses: 125.01260583333345
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=227.772, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=229.384, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=229.487, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=299.325, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=231.248, Time=0.22 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.608 seconds
# Modelo para el producto 20070 entrenado y guardado. Predicción a 2 meses: 115.75041333333337
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=236.399, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=236.823, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=238.107, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=236.375, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=301.562, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=239.762, Time=0.10 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=282.184, Time=0.07 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.956 seconds
# Modelo para el producto 20071 entrenado y guardado. Predicción a 2 meses: 121.42377815826596
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=230.642, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=230.026, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=228.754, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.648 seconds
# Modelo para el producto 20072 entrenado y guardado. Predicción a 2 meses: 32.2686
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=225.418, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=218.548, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=223.491, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=216.707, Time=0.10 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=215.878, Time=0.18 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=217.818, Time=0.20 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=215.729, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=215.883, Time=0.04 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=217.729, Time=0.07 sec
# ...
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=17.056, Time=0.26 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.18 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0] intercept
# Total fit time: 1.419 seconds
# Modelo para el producto 21006 entrenado y guardado. Predicción a 2 meses: 2.9136013954653808
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=14.072, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=10.989, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=12.639, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=27.023, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.379 seconds
# Modelo para el producto 21035 entrenado y guardado. Predicción a 2 meses: 1.8982499996760949
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=14.567, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=16.413, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=27.735, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.504 seconds
# Modelo para el producto 21039 entrenado y guardado. Predicción a 2 meses: 1.9819533333277612
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=21.874, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=18.002, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=18.583, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=19.232, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=27.656, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.366 seconds
# Modelo para el producto 21079 entrenado y guardado. Predicción a 2 meses: 1.8997366649353113
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=12.760, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=8.923, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=10.792, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=21.956, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.406 seconds
# Modelo para el producto 21109 entrenado y guardado. Predicción a 2 meses: 1.2232383328427274
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=7.769, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=6.253, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=7.920, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=20.375, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.516 seconds
# Modelo para el producto 21112 entrenado y guardado. Predicción a 2 meses: 1.0800566665347562
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=49.818, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=51.807, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=51.850, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=60.210, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.461 seconds
# Modelo para el producto 20213 entrenado y guardado. Predicción a 2 meses: 78.12020799999996
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=49.669, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=46.041, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=48.005, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=47.171, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=57.206, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.464 seconds
# Modelo para el producto 20257 entrenado y guardado. Predicción a 2 meses: 58.229854
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=33.138, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=29.909, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=31.808, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=31.075, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=38.546, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.426 seconds
# Modelo para el producto 20694 entrenado y guardado. Predicción a 2 meses: 8.777970000000003
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=29.118, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=26.260, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=28.259, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=35.902, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.506 seconds
# Modelo para el producto 20762 entrenado y guardado. Predicción a 2 meses: 6.8208
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=21.567, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=18.592, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=20.591, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=36.387, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.448 seconds
# Modelo para el producto 20815 entrenado y guardado. Predicción a 2 meses: 7.464221999999999
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=18.166, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=18.291, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=16.149, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=17.265, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=27.780, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=24.132, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.462 seconds
# Modelo para el producto 20899 entrenado y guardado. Predicción a 2 meses: 2.518571121494407
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=15.717, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=18.616, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=14.016, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=25.624, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=24.886, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.405 seconds
# Modelo para el producto 20942 entrenado y guardado. Predicción a 2 meses: 1.9068368212024236
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=15.578, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=14.405, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=13.946, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=27.329, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=21.458, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.561 seconds
# Modelo para el producto 20968 entrenado y guardado. Predicción a 2 meses: 2.4396932057563303
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=13.749, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=9.749, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=11.709, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=11.720, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=21.490, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.289 seconds
# Modelo para el producto 21058 entrenado y guardado. Predicción a 2 meses: 1.6437799987791017
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=9.517, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=5.713, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=7.617, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=7.520, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19.613, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.413 seconds
# Modelo para el producto 21097 entrenado y guardado. Predicción a 2 meses: 1.3787139999999936
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=9.118, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=6.366, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=8.066, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19.730, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.435 seconds
# Modelo para el producto 21110 entrenado y guardado. Predicción a 2 meses: 1.3914519999725101
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-3.184, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=5.519, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2.643, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=15.881, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=12.409, Time=0.13 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 0.613 seconds
# Modelo para el producto 21129 entrenado y guardado. Predicción a 2 meses: 0.79415925813708
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=18.435, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=14.876, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=16.854, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=16.852, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19.416, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.500 seconds
# Modelo para el producto 21144 entrenado y guardado. Predicción a 2 meses: 1.1794199977756563
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=14.875, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=11.220, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=12.939, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=12.901, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18.781, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.385 seconds
# Modelo para el producto 21146 entrenado y guardado. Predicción a 2 meses: 1.1963379993840508
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=15.820, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=17.817, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=21.085, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19.788, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.520 seconds
# Modelo para el producto 21154 entrenado y guardado. Predicción a 2 meses: 1.1963219970466492
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=56.068, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=58.008, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=57.965, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.566 seconds
# Modelo para el producto 20127 entrenado y guardado. Predicción a 2 meses: 208.43745000000004
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=46.987, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=48.572, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=49.977, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.261 seconds
# Modelo para el producto 20210 entrenado y guardado. Predicción a 2 meses: 82.17732000000004
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=23.499, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=24.994, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=33.748, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.350 seconds
# Modelo para el producto 20686 entrenado y guardado. Predicción a 2 meses: 12.498402500000001
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=25.059, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=26.805, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=26.208, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=33.636, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.237 seconds
# Modelo para el producto 20703 entrenado y guardado. Predicción a 2 meses: 12.166955000000002
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=19.098, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=20.429, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=20.110, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=24.887, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.281 seconds
# Modelo para el producto 20962 entrenado y guardado. Predicción a 2 meses: 3.915682499999998
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=18.994, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=20.280, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=24.271, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.307 seconds
# Modelo para el producto 20975 entrenado y guardado. Predicción a 2 meses: 3.5839899999999973
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=20.796, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=18.276, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=19.615, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=19.392, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=23.733, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.329 seconds
# Modelo para el producto 20995 entrenado y guardado. Predicción a 2 meses: 3.3653224999999996
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=7.923, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=9.863, Time=0.12 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=13.269, Time=0.02 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.498 seconds
# Modelo para el producto 21087 entrenado y guardado. Predicción a 2 meses: 0.907422499309475
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4.327, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4.850, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=7.516, Time=0.02 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.618 seconds
# Modelo para el producto 21214 entrenado y guardado. Predicción a 2 meses: 0.41106249974285336

# %%
predictions_df = pd.DataFrame(predictions)
predictions_df.to_csv('../../Datasets/predictions.csv', index=False)

print('Todas las predicciones han sido generadas y guardadas en predictions.csv.')
# Out:
# Todas las predicciones han sido generadas y guardadas en predictions.csv.
